# %% [markdown]
# # 因子评价与回测
# 1. 通过高频数据低频化，拟合成日频因子，预测t+1开盘到t+2开盘的收益，回测也用t+1开盘到t+2开盘的收益率进行回测;
# 2. 评价流程主要为IC、ICIR，以及因子回测;
# 3. 由于期货品种较少，回测中我们用全品种交易，因子值即为仓位比例，因此不做分层测试;
# 4. 所有的单因子测试code整理至Single_Factor_Test.py中;
# 5. 最后根据因子间相关性、因子表现来筛选相关性低于0.5的因子。

# %%
from Single_Factor_Test import *

# %% [markdown]
# ## CPV_corr_price_1_N_vol

# %%
Test_Engine = Factor_Evaluation("CPV_corr_price_1_N_vol",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014  0.0564    1.06  1.44  0.0391 -0.35   2.35
# 2015  0.0691    0.72  0.71  0.0979 -2.22  19.97
# 2016  0.0087    0.09  0.12  0.0713  0.07   0.93
# 2017  0.0901    1.14  1.41  0.0637 -0.49   2.31
# 2018  0.0572    1.08  1.37  0.0416 -0.35   1.12
# 2019 -0.0518   -1.01 -0.96  0.0538 -0.49   2.40
# 2020 -0.1877   -2.07 -0.97  0.1938 -0.97  15.01
# 2021 -0.1191   -1.33 -0.82  0.1449 -0.32   2.65

# %% [markdown]
# ## CPV_corr_price_l1_N_vol

# %%
Test_Engine = Factor_Evaluation("CPV_corr_price_l1_N_vol",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014  0.0563    1.04  1.50  0.0376 -0.35   2.00
# 2015  0.0546    0.57  0.54  0.1005 -2.21  19.27
# 2016 -0.0329   -0.34 -0.39  0.0847 -0.06   1.35
# 2017  0.0826    1.04  1.18  0.0697 -0.44   2.02
# 2018  0.0353    0.66  0.89  0.0397 -0.43   1.46
# 2019 -0.0438   -0.84 -0.91  0.0479 -0.38   2.39
# 2020 -0.2385   -2.65 -1.10  0.2171 -1.08  14.28
# 2021 -0.1444   -1.61 -0.88  0.1637 -0.41   2.99

# %% [markdown]
# ## CPV_corr_price_N_vol

# %%
Test_Engine = Factor_Evaluation("CPV_corr_price_N_vol",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014  0.0573    1.09  1.62  0.0353 -0.38   2.40
# 2015  0.0723    0.75  0.75  0.0958 -2.22  19.66
# 2016 -0.0027   -0.03 -0.04  0.0732  0.09   1.02
# 2017  0.0712    0.89  0.96  0.0744 -0.52   2.28
# 2018  0.0453    0.85  1.09  0.0415 -0.37   1.09
# 2019 -0.0527   -1.01 -0.96  0.0548 -0.48   2.25
# 2020 -0.1882   -2.05 -0.96  0.1969 -0.68  13.76
# 2021 -0.1256   -1.41 -0.86  0.1466 -0.39   2.62

# %% [markdown]
# ## CPV_corr_ret_1_N_vol

# %%
Test_Engine = Factor_Evaluation("CPV_corr_ret_1_N_vol",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度    峰度
# 2014 -0.0258   -0.54 -0.53  0.0488 -0.01  0.53
# 2015  0.1059    1.42  2.38  0.0445  1.06  4.60
# 2016  0.1308    1.41  1.63  0.0804  0.69  8.09
# 2017  0.1017    1.49  3.03  0.0335  0.16  4.18
# 2018  0.1126    2.23  6.08  0.0185  0.17  0.24
# 2019  0.0456    1.04  2.37  0.0192 -0.48  1.27
# 2020 -0.0276   -0.34 -0.46  0.0605 -0.13  8.74
# 2021  0.0781    0.93  1.53  0.0511  0.46  1.40

# %% [markdown]
# ## CPV_corr_ret_l1_N_vol

# %%
Test_Engine = Factor_Evaluation("CPV_corr_ret_l1_N_vol",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度    峰度
# 2014 -0.0113   -0.20 -0.25  0.0455 -0.45  0.61
# 2015  0.0858    0.81  1.53  0.0559 -0.25  8.29
# 2016  0.1909    1.81  4.90  0.0390  0.48  1.23
# 2017  0.1045    1.24  1.65  0.0633 -0.32  1.46
# 2018  0.0307    0.49  0.56  0.0545 -0.02  0.67
# 2019  0.0779    1.40  3.92  0.0199 -0.13  0.93
# 2020 -0.0445   -0.49 -0.35  0.1282 -0.23  6.02
# 2021  0.1999    2.00  3.56  0.0561  0.31  2.19

# %% [markdown]
# ## CPV_corr_ret_N_vol

# %%
Test_Engine = Factor_Evaluation("CPV_corr_ret_N_vol",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度    峰度
# 2014 -0.0153   -0.27 -0.31  0.0485 -0.04  0.41
# 2015  0.0975    1.06  1.26  0.0771 -0.83  4.72
# 2016  0.2359    2.34  5.29  0.0446  0.07  1.01
# 2017  0.0536    0.65  0.72  0.0745 -0.10  1.10
# 2018  0.0626    0.95  1.10  0.0571  0.08  1.55
# 2019  0.0437    0.77  1.20  0.0365 -0.27  1.16
# 2020  0.0884    0.93  0.91  0.0967  0.17  4.22
# 2021  0.2202    2.10  4.66  0.0473  0.57  2.31

# %% [markdown]
# ## Diff_10_20_ret_res

# %%
Test_Engine = Factor_Evaluation("Diff_10_20_ret_res",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014  0.0323    0.24  0.31  0.1055  0.26   3.73
# 2015  0.2335    0.70  0.65  0.3614 -0.34   9.70
# 2016  0.3477    1.77  4.59  0.0757  0.46   1.69
# 2017 -0.1156   -0.64 -0.42  0.2723  0.23   3.06
# 2018 -0.0304   -0.24 -0.30  0.1008 -0.37   1.75
# 2019 -0.0498   -0.46 -0.30  0.1652 -0.02   1.58
# 2020 -0.0015   -0.01 -0.01  0.1830 -0.83  10.78
# 2021  0.4931    2.20  5.79  0.0852  0.77   3.44

# %% [markdown]
# ## Diff_10_mean_ret_res

# %%
Test_Engine = Factor_Evaluation("Diff_10_mean_ret_res",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014  0.0360    0.26  0.32  0.1123  0.36   3.37
# 2015  0.1413    0.42  0.37  0.3781 -0.97  10.81
# 2016  0.3875    1.96  5.08  0.0763  0.46   1.63
# 2017 -0.1084   -0.58 -0.38  0.2851  0.32   3.13
# 2018 -0.0211   -0.16 -0.19  0.1099 -0.34   1.57
# 2019 -0.0412   -0.37 -0.27  0.1543 -0.01   1.65
# 2020 -0.0165   -0.08 -0.08  0.1987 -0.85  10.46
# 2021  0.5424    2.43  6.44  0.0842  0.81   3.65

# %% [markdown]
# ## Diff_top10_bot90

# %%
Test_Engine = Factor_Evaluation("Diff_top10_bot90",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014  0.0361    0.26  0.32  0.1122  0.36   3.37
# 2015  0.1417    0.42  0.37  0.3781 -0.97  10.82
# 2016  0.3876    1.96  5.08  0.0763  0.46   1.63
# 2017 -0.1081   -0.58 -0.38  0.2849  0.33   3.14
# 2018 -0.0211   -0.16 -0.19  0.1099 -0.34   1.57
# 2019 -0.0412   -0.37 -0.27  0.1543 -0.01   1.65
# 2020 -0.0167   -0.08 -0.08  0.1988 -0.85  10.46
# 2021  0.5423    2.43  6.44  0.0842  0.81   3.66

# %% [markdown]
# ## Mean_ret_res

# %%
Test_Engine = Factor_Evaluation("Mean_ret_res",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014 -0.0484   -0.36 -0.31  0.1564  0.25   3.32
# 2015 -0.0407   -0.13 -0.11  0.3605 -1.69  10.55
# 2016  0.3872    1.97  4.73  0.0818  0.45   1.79
# 2017 -0.1181   -0.63 -0.39  0.3021  0.38   3.26
# 2018 -0.0175   -0.14 -0.16  0.1116 -0.27   1.47
# 2019 -0.0338   -0.30 -0.24  0.1435  0.01   1.62
# 2020 -0.0658   -0.32 -0.28  0.2361 -0.78   9.59
# 2021  0.6275    2.88  9.01  0.0697  0.84   3.78

# %% [markdown]
# ## Top10_mean_ret_res

# %%
Test_Engine = Factor_Evaluation("Top10_mean_ret_res",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014  0.0271    0.20  0.23  0.1155  0.35   3.34
# 2015  0.1374    0.41  0.37  0.3748 -1.04  10.70
# 2016  0.3904    1.97  5.08  0.0768  0.45   1.65
# 2017 -0.1092   -0.59 -0.38  0.2874  0.33   3.13
# 2018 -0.0203   -0.16 -0.18  0.1102 -0.33   1.56
# 2019 -0.0402   -0.37 -0.26  0.1529 -0.01   1.64
# 2020 -0.0232   -0.11 -0.11  0.2040 -0.84  10.37
# 2021  0.5508    2.48  6.62  0.0832  0.81   3.68

# %% [markdown]
# ## Top20_mean_ret_res

# %%
Test_Engine = Factor_Evaluation("Top20_mean_ret_res",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014  0.0320    0.24  0.28  0.1130  0.37   3.20
# 2015  0.0127    0.04  0.03  0.3711 -1.50  11.09
# 2016  0.4165    2.13  5.45  0.0764  0.46   1.76
# 2017 -0.0994   -0.53 -0.34  0.2946  0.41   3.37
# 2018 -0.0137   -0.11 -0.12  0.1167 -0.29   1.42
# 2019 -0.0313   -0.28 -0.22  0.1405  0.01   1.72
# 2020 -0.0377   -0.18 -0.17  0.2212 -0.88  10.10
# 2021  0.6002    2.74  7.93  0.0757  0.83   3.94

# %% [markdown]
# ## Whole_tide_3

# %%
Test_Engine = Factor_Evaluation("Whole_tide_3",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度    峰度
# 2014 -0.0018   -0.02 -0.03  0.0543 -0.49  1.39
# 2015  0.2645    1.49  3.10  0.0854  0.12  7.34
# 2016  0.1566    1.23  2.51  0.0623  0.25  1.70
# 2017  0.1635    1.34  1.94  0.0842  0.25  2.68
# 2018  0.0390    0.50  0.55  0.0716 -0.11  1.12
# 2019  0.1005    1.60  4.27  0.0235 -0.12  1.50
# 2020  0.0486    0.48  0.43  0.1130  0.62  4.37
# 2021  0.1316    1.12  1.85  0.0713  0.33  0.79

# %% [markdown]
# ## Whole_tide_5

# %%
Test_Engine = Factor_Evaluation("Whole_tide_5",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度    峰度
# 2014 -0.0165   -0.21 -0.20  0.0843 -0.48  1.17
# 2015  0.2083    1.15  2.40  0.0867  0.03  8.18
# 2016  0.1842    1.47  3.36  0.0548  0.28  1.10
# 2017  0.1625    1.29  1.71  0.0951  0.21  2.83
# 2018  0.0340    0.44  0.59  0.0580 -0.05  0.83
# 2019  0.0684    1.13  2.28  0.0300 -0.42  1.44
# 2020 -0.0245   -0.23 -0.17  0.1454 -0.34  5.41
# 2021  0.2191    1.76  2.28  0.0961  0.02  1.89

# %% [markdown]
# ## Whole_tide_7

# %%
Test_Engine = Factor_Evaluation("Whole_tide_7",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度    峰度
# 2014  0.0039    0.05  0.06  0.0636 -0.45  0.98
# 2015  0.1882    1.00  2.48  0.0760 -0.03  7.04
# 2016  0.1891    1.46  3.53  0.0536  0.27  1.57
# 2017  0.1317    1.08  1.43  0.0921  0.15  2.43
# 2018  0.0741    0.97  1.11  0.0665  0.08  0.84
# 2019  0.0966    1.52  2.60  0.0372 -0.44  1.43
# 2020 -0.0303   -0.30 -0.21  0.1424 -0.70  5.63
# 2021  0.1916    1.45  1.87  0.1022  0.01  2.30

# %% [markdown]
# ## Whole_tide_9

# %%
Test_Engine = Factor_Evaluation("Whole_tide_9",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度    峰度
# 2014 -0.0694   -0.86 -0.72  0.0962 -0.53  0.81
# 2015  0.2224    1.20  2.89  0.0769  0.11  8.01
# 2016  0.2057    1.58  3.02  0.0681  0.24  2.00
# 2017  0.1698    1.37  2.06  0.0823  0.34  3.03
# 2018  0.0673    0.85  1.06  0.0634  0.06  0.86
# 2019  0.0916    1.45  3.92  0.0234 -0.26  0.96
# 2020 -0.0087   -0.08 -0.06  0.1390 -0.74  6.36
# 2021  0.1324    0.96  1.09  0.1213 -0.36  3.53

# %% [markdown]
# ## ext_ret

# %%
Test_Engine = Factor_Evaluation("ext_ret",direction=-1)

# %%
Test_Engine.calc_ic_plot()

# %%
Test_Engine.plot_pnl()

# %%
Test_Engine.calculate_strategy_metrics()
# Out:
#        年化收益率  年化夏普比率  卡玛比率    最大回撤    偏度     峰度
# 2014 -0.0313   -0.58 -0.55  0.0568  0.06   1.76
# 2015  0.0402    0.37  0.31  0.1302 -1.76  10.85
# 2016  0.2269    2.26  5.80  0.0391  0.15   2.03
# 2017 -0.1063   -1.32 -0.73  0.1457 -0.17   1.36
# 2018 -0.0204   -0.33 -0.32  0.0634 -0.42   2.08
# 2019 -0.0183   -0.37 -0.27  0.0676 -0.53   2.08
# 2020  0.0912    0.95  1.07  0.0851 -0.49   7.33
# 2021  0.2413    2.34  5.52  0.0437  0.78   3.30
